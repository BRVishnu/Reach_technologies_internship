# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\\reach_technologies_internship\\joblistings.csv",index_col=0)

# %%
df2=pd.read_csv("D:\\reach_technologies_internship\\Book1.csv",index_col=0)

# %%
df2.head()
# Out:
#                                            Job Title  \
# 0  Machine Learning/Artificial Intelligence Engin...
# 1                                   Dot Net Trainer
# 2                                Software Developer
# 3                                      Web Designer
# 4                                Software Developer
#
#                  Company Name     Salary    Location  \
# 0  Nuevalgo Solutions pvt ltd  2 L - 4 L  Trivandrum
# 1           Connecting 2 Work  2 L - 4 L  Trivandrum
# 2           AiMSoft Solutions  3 L - 5 L  Trivandrum
# 3           AiMSoft Solutions  3 L - 5 L  Trivandrum
# 4           AiMSoft Solutions  2 L - 4 L  Trivandrum
#
#                                      Company Profile
# 0  CYBOSOL, since its inception in 2009, has been...
# 1  Connecting2Work HR Solutions offer HR Consulti...
# 2  AiMSoftSolutions is a rapidly growing custom d...
# 3  AiMSoftSolutions is a rapidly growing custom d...
# 4  AiMSoftSolutions is a rapidly growing custom d...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4170 entries, 0 to 4169
# Data columns (total 3 columns):
# Job Title       4170 non-null object
# Company Name    4170 non-null object
# Salary          4170 non-null object
# dtypes: object(3)
# memory usage: 130.3+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3802 entries, 0 to 3801
# Data columns (total 5 columns):
# Job Title          3802 non-null object
# Company Name       3802 non-null object
# Salary             3802 non-null object
# Location           3802 non-null object
# Company Profile    3802 non-null object
# dtypes: object(5)
# memory usage: 178.2+ KB

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Machine Learning/Artificial Intelligence Engin...
# 1                                   Dot Net Trainer
# 2                                Software Developer
# 3                                      Web designer
# 4                                      Web Designer
#
#                  Company Name     Salary
# 0  Nuevalgo Solutions pvt ltd  2 L - 4 L
# 1           Connecting 2 Work  2 L - 4 L
# 2           AiMSoft Solutions  3 L - 5 L
# 3           Ofek Technologies  2 L - 4 L
# 4           AiMSoft Solutions  3 L - 5 L

# %%
df2["Company Name"].unique()
# Out:
# array(['Nuevalgo Solutions pvt ltd', 'Connecting 2 Work',
#        'AiMSoft Solutions', 'ANIMATIONS MEDIA',
#        'Toonz Animation India Pvt.',
#        'Integrated Dynamic Solutions India Pvt Ltd',
#        'Vinvish Technologies Pvt. Ltd.', 'EPICA STUDIO PVT LTD.',
#        'Deep Thought Systems (P) Ltd', 'Ofek Technologies',
#        'Trans Software Solutions', 'TBF Technology Pvt LTD', 'Dinadevan',
#        'Inzynix IT Solution', 'Vinvish Technologies Pvt. Ltd',
#        'Aenon Technologies Pvt Ltd',
#        'WebGlobal Technology Solution Pvt Ltd',
#        'QAWebPrints Info Solutions', 'Jehosh Solutions',
#        'INDEL MONEY PVT. LTD', 'Light Logics Holography and Optics',
#        'Mobatia', 'TrioCodes Technologies Pvt. Ltd.',
#        'Techversant Infotech', 'DBASE 4MEDIA PRIVATE LIMITED',
#        'InnoVal Digital Solutions Private Limited (IVL)',
#        'Olive Builders and Developers Pvt. Ltd.', 'Doctors Destination',
# ...

# %%
df2["Company Name"].nunique()
# Out:
# 38

# %%
job_title_group=df2.groupby(by="Job Title").count()

# %%
job_title_group.sort_values(by="Company Name",ascending=False)
# Out:
#                                                     Company Name  Salary  \
# Job Title
# Web Designer                                                 296     296
# DOC                                                          184     184
# Software Developer                                           180     180
# TRAINEE/ JUNIOR ENGINEERS                                    148     148
# Trainee  -  Functional Consultant                            132     132
# MARKETING RESEARCH ANALYST                                    96      96
# Sales and Marketing Engineer Trainee                          96      96
# Software Engineer Trainees                                    92      92
# Relationship Officers (MSME/LAP)                              92      92
# Sales Executive                                               92      92
# Sales Executive / Marketing Officer                           92      92
# Android App Developer                                         92      92
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 138
# Data columns (total 5 columns):
# Job Title          54 non-null object
# Company Name       54 non-null object
# Salary             54 non-null object
# Location           54 non-null object
# Company Profile    54 non-null object
# dtypes: object(5)
# memory usage: 2.5+ KB

# %%
df2.to_csv("D:\\reach_technologies_internship\\joblistings_2_cleaned.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 146
# Data columns (total 3 columns):
# Job Title       58 non-null object
# Company Name    58 non-null object
# Salary          58 non-null object
# dtypes: object(3)
# memory usage: 1.8+ KB

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.to_csv("D:\\reach_technologies_internship\\joblistings_cleaned.csv")
